# %%
import pandas as pd
df = pd.read_csv('Fault_Molucca_Sea_center (1)', sep='\t')
df['type'] = 0.5
df['risetime'] = 0.5
# print(df)
# print(df.columns)
column_order = ['longitude(degree)', 'latitude(degree)', ' depth(km)', ' strike(degree)', ' dip(degree)', 'type', 'risetime', ' length(km)', ' width(km)']
df= df[column_order]
print(df)
df.to_csv('sangihe.fault', sep=' ', header=False )
# Out:
#      longitude(degree)  latitude(degree)   depth(km)   strike(degree)  \
# 0              126.066             1.566        0.10             20.0
# 1              126.050             1.524        0.10             20.0
# 2              126.035             1.481        0.10             20.5
# 3              126.019             1.439        0.10             20.5
# 4              126.003             1.397        0.10             21.0
# ..                 ...               ...         ...              ...
# 295            126.162             0.437       31.92              7.7
# 296            126.157             0.398       31.92              7.0
# 297            126.152             0.358       31.92              6.3
# 298            126.148             0.319       31.92              5.6
# 299            126.144             0.279       31.92              4.9
#
#       dip(degree)  type  risetime   length(km)   width(km)
# 0              45   0.5       0.5            5           5
# ...
